# %%
from lakey_ui import discover, download

# %% [markdown]
# # DISCOVER

# %%
discover()

# %% [markdown]
# # DOWNLOAD

# %%
df = download()

# %%
df
# Out:
#    value         name
# 0    134  temperature
# 1    556  temperature
# 2    466  temperature
# 3    452  temperature
# 4    123  temperature
# 5   1235  temperature
# 6   4893  temperature
